# %% [markdown]
# <a href="https://colab.research.google.com/github/balakrishna15/Brain-Tumor-Dectection-Using-YOLOv8/blob/main/Brain_Tumor_Detection_using_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
#
# In this notebook we're going to build a computer vision model to detect brain tumors. In order to perform that, we'll be using [PyTorch](https://pytorch.org) and in particular we'll start from the [YOLOv8](https://github.com/ultralytics/yolov8) architecture to perform fine-tuning for this task. For building our models  we will use the medium version **YOLOv5m**.
#
# Furthermore, we'll use this dataset from Kaggle called "[Brain Tumor Object Detection Dataset](https://www.kaggle.com/datasets/davidbroberts/brain-tumor-object-detection-datasets)" which already includes the labels and the bounding boxes that will be used to train the model.
# It counts 1.274 images of MRI scans of the brain taken on 3 different axes:
#
# | Axial       | Coronal     | Sagittal    |
# | ----------- | ----------- | ----------- |
# | ![00022_75.jpg](data:image/jpeg;base64,...)      |![59 (8).jpg](data:image/jpeg;base64,...)        |      ![00002_166.jpg](data:image/jpeg;base64,...)       |
#
#
# Note that this dataset has been already imported in this repository.

# %% [markdown]
# # Workspace Configuration

# %%
# Global imports
import shutil
import zipfile
import os
import torch
import urllib.request
from IPython.display import Image, display

# %%
if not os.path.isdir("sampledata1"):
  os.makedirs("sampledata1")

# %%
# %cd sampledata1
# Out:
# /content/sampledata1

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 13695, done.
# remote: Counting objects: 100% (1356/1356), done.
# remote: Compressing objects: 100% (854/854), done.
# remote: Total 13695 (delta 767), reused 968 (delta 495), pack-reused 12339
# Receiving objects: 100% (13695/13695), 8.04 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (9080/9080), done.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.2/606.2 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# Download and unzip the dataset

if not os.path.isfile('data.zip'):
  urllib.request.urlretrieve("https://github.com/giuseppebrb/BrainTumorDetection/blob/main/data.zip?raw=true", "data.zip")

with zipfile.ZipFile("data.zip","r") as zip_ref:
    zip_ref.extractall(".")

os.remove('data.zip')

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/sampledata1/data/axial/axial.yaml epochs=20 imgsz=480 batch =64  name = axial_plane plots=True
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 382MB/s]
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
display(Image(filename='/content/sampledata1/runs/detect/axial_plane/confusion_matrix.png'))

# %% [markdown]
# ## Axial Plane Model

# %% [markdown]
# ### F1 Curve

# %%
display(Image(filename=''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-91c901a56121> in <cell line: 1>()
# ----> 1 display(Image(filename=''))
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1221
#    1222         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1223             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1224         if self.embed:
#    1225             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the '' image format

# %% [markdown]
# ### PR Curve

# %%
display(Image(filename=''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-91c901a56121> in <cell line: 1>()
# ----> 1 display(Image(filename=''))
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1221
#    1222         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1223             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1224         if self.embed:
#    1225             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the '' image format

# %% [markdown]
# ### Confusion Matrix

# %%
display(Image(filename=''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-91c901a56121> in <cell line: 1>()
# ----> 1 display(Image(filename=''))
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1221
#    1222         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1223             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1224         if self.embed:
#    1225             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the '' image format

# %% [markdown]
# ### Results summary

# %%
display(Image(filename=''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-91c901a56121> in <cell line: 1>()
# ----> 1 display(Image(filename=''))
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1221
#    1222         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# -> 1223             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#    1224         if self.embed:
#    1225             self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the '' image format

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/sampledata1/data/coronal/coronal.yaml epochs=20 imgsz=480 batch =64 name = coronol_plane plots=True
# Out:
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### F1 Curve

# %%
display(Image(filename=''))

# %% [markdown]
# ### PR Curve

# %%
display(Image(filename=''))

# %% [markdown]
# ### Confusion Matrix

# %%
display(Image(filename=''))

# %% [markdown]
# ### Results Summary

# %%
display(Image(filename=''))

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/sampledata1/data/sagittal/sagittal.yaml epochs=20 imgsz=480 batch =64 name = sagittal_plane plots=True
# Out:
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Sagittal Plane Model

# %% [markdown]
# ### F1 Curve

# %%
display(Image(filename=''))

# %% [markdown]
# ### PR Curve

# %%
display(Image(filename=''))

# %% [markdown]
# ### Confusion Matrix

# %%
display(Image(filename=''))

# %% [markdown]
# ### Results

# %%
display(Image(filename=''))

# %% [markdown]
# # Testing the models

# %% [markdown]
# Let's test our models with never seen images during the training.

# %%
# !yolo predict model=runs/detect/axial_plane/weights/best.pt conf = 0.4 source = /content/sampledata1/data/axial/images/test/00018_101.jpg
# Out:
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/1 /content/sampledata1/data/axial/images/test/00018_101.jpg: 480x480 1 not tumor, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 480)
# Results saved to runs/detect/predict

# %%
# !yolo predict model=runs/detect/axial_plane2/weights/best.pt conf = 0.4 source = /content/Y18.JPG
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 396, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 94, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 140, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 621, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 560, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
# ...

# %%
display(Image(filename='/content/sampledata1/runs/detect/predict/00018_101.jpg'))

# %% [markdown]
# ## Axial Model

# %%
display(Image(filename='/content/sampledata1/runs/detect/predict2/Y3.jpg'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-39f9c9bed8e4> in <cell line: 1>()
# ----> 1 display(Image(filename='/content/sampledata1/runs/detect/predict2/Y3.jpg'))
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
# !yolo predict model=runs/detect/axial_plane/weights/best.pt conf = 0.4 source=https://prod-images-static.radiopaedia.org/images/5651/b510dc0d5cd3906018c4dd49b98643_gallery.jpeg
# Out:
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# ...
# 100% 27.7k/27.7k [00:00<00:00, 48.1MB/s]
# image 1/1 /content/sampledata1/b510dc0d5cd3906018c4dd49b98643_gallery.jpeg: 480x480 1 tumor, 10.8ms
# Speed: 3.6ms preprocess, 10.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 480)
# Results saved to runs/detect/predict2

# %%
display(Image(filename='/content/sampledata1/runs/detect/predict/b510dc0d5cd3906018c4dd49b98643_gallery.jpeg'))

# %%
# !yolo predict model=runs/detect/coronol_plane_plane/weights/best.pt conf = 0.4 source = https://www.mriclinicalcasemap.philips.com/content/images/cases/case154/thumbs/14.jpg
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 396, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 94, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 140, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 621, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 560, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
# ...

# %% [markdown]
# ## Coronal Model

# %%
# !yolo predict model=runs/detect/sagattial_plane_plane/weights/best.pt conf = 0.4 source = https://prod-images-static.radiopaedia.org/images/4440984/10a4749375e20983b677e0502a9d7f_gallery.jpg
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 396, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 94, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 140, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 621, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 560, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
# ...

# %% [markdown]
# ## Sagittal Model
